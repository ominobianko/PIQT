# %%
import pandas as pd
import os  
from pathlib import Path
from bs4 import BeautifulSoup

# %%
#fuznione estrai titolo per definizione test 
def titoli(ffile, tag):
    t=[]
    f =  Path(ffile).read_text()
    soup=BeautifulSoup(f)
    a=soup.find_all(tag)
    for x in a:
        b=x.getText()
        t.append(b) 
    #print(t)
    return (t)

# %%
#funzione estrai deal file f le tabelle HTML e seleziona quelle con in dati utili

def estraitabelle (f):

    tabelleHTML = pd.read_html(f,header=None)
    #tabelleHTML.drop(columns=a.columns[-1:], axis=1,  inplace=True)
    selected=[]
    for i in [2, 5, 8, 11]:
        temp=[tabelleHTML[i]]
        selected=selected+temp
    return selected

# %%
def Tabella (sergente, x):
    #C è la lista dei dataframe estratti
    C=[]
    a=estraitabelle(sergente)
    b=titoli(sergente,'span')
    A=a[x].transpose()
    A.columns = A.iloc[0]
    A = A[1:]
    A.insert(0,'QATest',b[x])
    temp=[A]
    C=C+temp
    #print(a)
    return C

# %%
#Analizza la cartella 
import os  

cartella= 'user'

m=os.listdir(cartella)
fuori=[]
for x in range (0, 4):

    #print (len(m))
    for n in range(0, len(m)):
        path=cartella+'/'+str(m[n])
        fuori=fuori+Tabella(path,x)

# %%
#concatena tutte le tabelle estratte con funzione tabella in un unico dataframe

out=[]
out = pd.concat(fuori, axis=0, ignore_index=True)
out.drop_duplicates()
out.to_csv('out.csv',index=False,)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=da728906-b508-42a4-90c9-ab2dfcd7f4b8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
